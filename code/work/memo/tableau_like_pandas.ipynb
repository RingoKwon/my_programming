# %%
import pandas as pd 
# !pip install pygwalker

import pygwalker as pyg

# %%
df = pd.read_csv('/Users/ringokwon/Desktop/ringo_workbook/code/work/memo/Result_937.csv')

# %%
df.head()
# Out:
#                                navi affiliate_id_affiliate absolute_control  \
# 0                 affiliate_landing                    NaN              NaN
# 1                             other                    NaN          control
# 2  affiliate_plan_finder_select_mno                paybooc     experimental
# 3           short_plan_finder_intro                    NaN          control
# 4                 affiliate_landing                paybooc     experimental
#
#   first_reg_date  is_apply  is_plan_detail  uuid_cnt  is_complete  is_kr
# 0     2023-04-11         3              29      3007            3     31
# 1     2023-06-14       271             175      1236           73    357
# 2     2023-06-16        10               4       176            0     11
# 3     2023-06-20         2               1        27            0      2
# 4     2023-06-09        21               7       379            2     25

# %%
from pandasai import PandasAI

# %%
from pandasai.llm.openai import OpenAI
llm = OpenAI(api_token='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')

# %%
pandas_ai = PandasAI(llm, conversational=False )

# %%
pandas_ai.run( df, 'do eda')
# Out:
# INFO: Question: do eda
# INFO: Running PandasAI with openai LLM...
# INFO: Prompt ID: 47babe1f-11ac-4d86-94d9-d47874a9e671
# INFO:
#                         Code generated:
#                         ```
#                         import pandas as pd
#
# # Load the dataframe
# df = pd.DataFrame({
#     'navi': ['affiliate_landing', 'short_plan_finder_intro', 'other', 'affiliate_landing', 'affiliate_plan_finder_select_mno'],
#     'affiliate_id_affiliate': [float('nan'), float('nan'), 'paybooc', 'paybooc', float('nan')],
#     'absolute_control': [float('nan'), 'control', 'experimental', 'experimental', 'control'],
#     'first_reg_date': ['2023-06-20', '2023-06-16', '2023-04-11', '2023-06-14', '2023-06-09'],
#     'is_apply': [21, 10, 271, 3, 2],
#     'is_plan_detail': [1, 175, 7, 4, 29],
#     'uuid_cnt': [1236, 379, 176, 3007, 27],
#     'is_complete': [73, 3, 2, 0, 0],
#     'is_kr': [25, 357, 31, 11, 2]
# })
#
# # Perform exploratory data analysis (EDA)
# ...

# %%
pandas_ai.run( df, 'do eda with plot')
# Out:
# INFO: Question: do eda with plot
# INFO: Running PandasAI with openai LLM...
# INFO: Prompt ID: 48bd81a3-1bb5-4208-9c2e-8d509bd03b47
# INFO:
#                         Code generated:
#                         ```
#                         import pandas as pd
# import matplotlib.pyplot as plt
#
# # Load the dataframe
# df = pd.DataFrame({
#     'navi': ['short_plan_finder_intro', 'affiliate_plan_finder_select_mno', 'affiliate_landing', 'affiliate_landing', 'other'],
#     'affiliate_id_affiliate': ['nan', 'paybooc', 'paybooc', 'nan', 'nan'],
#     'absolute_control': ['experimental', 'experimental', 'nan', 'control', 'control'],
#     'first_reg_date': ['2023-06-20', '2023-06-16', '2023-04-11', '2023-06-14', '2023-06-09'],
#     'is_apply': [271, 10, 2, 3, 21],
#     'is_plan_detail': [4, 1, 29, 7, 175],
#     'uuid_cnt': [27, 176, 379, 3007, 1236],
#     'is_complete': [73, 3, 2, 0, 0],
#     'is_kr': [357, 11, 2, 31, 25]
# })
#
# # Perform EDA with plots
# ...

# %%
pandas_ai.run( df, 'show me relationship')
# Out:
# INFO: Question: show me relationship
# INFO: Running PandasAI with openai LLM...
# INFO: Prompt ID: 492394c6-810c-4b13-9836-ca7d575909ef
# INFO:
#                         Code generated:
#                         ```
#                         import pandas as pd
#
# # Create the dataframe
# data = {'navi': ['affiliate_landing', 'affiliate_plan_finder_select_mno', 'short_plan_finder_intro', 'other', 'affiliate_landing'],
#         'affiliate_id_affiliate': ['paybooc', 'nan', 'nan', 'nan', 'paybooc'],
#         'absolute_control': ['control', 'experimental', 'nan', 'control', 'experimental'],
#         'first_reg_date': ['2023-06-20', '2023-06-14', '2023-04-11', '2023-06-09', '2023-06-16'],
#         'is_apply': [3, 271, 21, 2, 10],
#         'is_plan_detail': [175, 4, 1, 29, 7],
#         'uuid_cnt': [27, 176, 1236, 379, 3007],
#         'is_complete': [73, 0, 0, 3, 2],
#         'is_kr': [357, 2, 31, 11, 25]}
#
# df = pd.DataFrame(data)
#
# # Print the relationship between columns
# ...

# %%
pandas_ai.run( df, 'show me relationship scatter plot')
# Out:
# INFO: Question: show me relationship scatter plot
# INFO: Running PandasAI with openai LLM...
# INFO: Prompt ID: 50883d21-c66a-44c3-af04-7a7429c36491
# INFO:
#                         Code generated:
#                         ```
#                         import pandas as pd
# import matplotlib.pyplot as plt
#
# # Read the dataframe
# df = pd.read_csv('data.csv')
#
# # Plot the scatter plot
# plt.scatter(df['uuid_cnt'], df['is_complete'])
# plt.xlabel('UUID Count')
# plt.ylabel('Is Complete')
# plt.title('Relationship Scatter Plot')
# plt.show()
#                         ```
#
# INFO:
# Code running:
# ```
# plt.scatter(df['uuid_cnt'], df['is_complete'])
# plt.xlabel('UUID Count')
# plt.ylabel('Is Complete')
# plt.title('Relationship Scatter Plot')
# plt.show(block=False)
# plt.close('all')
# ```
# INFO: Answer: None
# INFO: Executed in: 2.9694931507110596s

# %%
pandas_ai.run( df, 'show me relationship scatter plot x,y as log')
# Out:
# INFO: Question: show me relationship scatter plot x,y as log
# INFO: Running PandasAI with openai LLM...
# INFO: Prompt ID: 461b76bb-8a4c-4523-a0ca-26e75a34f6c8
# INFO:
#                         Code generated:
#                         ```
#                         import matplotlib.pyplot as plt
#
# # Convert x and y columns to log scale
# df['x_log'] = np.log(df['x'])
# df['y_log'] = np.log(df['y'])
#
# # Create scatter plot
# plt.scatter(df['x_log'], df['y_log'])
# plt.xlabel('x (log scale)')
# plt.ylabel('y (log scale)')
# plt.title('Relationship between x and y (log scale)')
# plt.show()
#                         ```
#
# INFO:
# Code running:
# ```
# df['x_log'] = np.log(df['x'])
# df['y_log'] = np.log(df['y'])
# plt.scatter(df['x_log'], df['y_log'])
# plt.xlabel('x (log scale)')
# plt.ylabel('y (log scale)')
# plt.title('Relationship between x and y (log scale)')
# plt.show(block=False)
# plt.close('all')
# ```
# WARNING: Error executing code (count: 0)
# ...

# %%
pandas_ai.run( df, 'show me relationship scatter plot x,y as log')
# Out:
# INFO: Question: show me relationship scatter plot x,y as log
# INFO: Running PandasAI with openai LLM...
# INFO: Prompt ID: 22f8bc75-3fa2-4ed1-9daa-5561747b7789
# INFO: Using cached response
# INFO:
# Code running:
# ```
# df['x_log'] = np.log(df['x'])
# df['y_log'] = np.log(df['y'])
# plt.scatter(df['x_log'], df['y_log'])
# plt.xlabel('x (log scale)')
# plt.ylabel('y (log scale)')
# plt.title('Relationship between x and y (log scale)')
# plt.show(block=False)
# plt.close('all')
# ```
# WARNING: Error executing code (count: 0)
# WARNING: Error executing code (count: 1)
# WARNING: Error executing code (count: 2)
# INFO: Answer: None
# INFO: Executed in: 13.25997805595398s

# %%
pandas_ai.run( df, 'show me relationship scatter plot conditional format')
# Out:
# INFO: Question: show me relationship scatter plot conditional format
# INFO: Running PandasAI with openai LLM...
# INFO: Prompt ID: 9b4b0600-01f1-47a2-95a6-9c7be6ccc875
# The server is overloaded or not ready yet.
# 'Unfortunately, I was not able to answer your question, because of the following error:\n\nThe server is overloaded or not ready yet.\n'
