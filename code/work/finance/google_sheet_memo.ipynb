# %%
import pandas as pd
import gspread
from google.oauth2.service_account import Credentials
import awswrangler  as wr
import json
import boto3
from io import BytesIO
# data-parse@evident-display-364004.iam.gserviceaccount.com

# %%
# !pip install gspread

# %%
credential_json = {
  "type": "service_account",
  "project_id": "evident-display-364004",
  "private_key_id": "b8b16e6042f500f944050246229abf14a061cb17",
  "private_key": "-----BEGIN PRIVATE KEY-----\\n-----END PRIVATE KEY-----\n",
  "client_email": "data-parse@evident-display-364004.iam.gserviceaccount.com",
  "client_id": "102592330267229412304",
  "auth_uri": "https://accounts.google.com/o/oauth2/auth",
  "token_uri": "https://oauth2.googleapis.com/token",
  "auth_provider_x509_cert_url": "https://www.googleapis.com/oauth2/v1/certs",
  "client_x509_cert_url": "https://www.googleapis.com/robot/v1/metadata/x509/data-parse%40evident-display-364004.iam.gserviceaccount.com"
}

# %%
def read_spreadsheet(sample_spreadsheet_id, tab_index):
    
    gc = gspread.service_account_from_dict(credential_json)
    
    gc = gc.open_by_key(sample_spreadsheet_id)
    
    values = gc.get_worksheet(tab_index).get_all_values()
    
    df = pd.DataFrame(values)
    df.columns = df.iloc[0]
    df.drop(df.index[0], inplace=True)         

    return df

# %%
#  df_grade = read_spreadsheet("1osPAN34sSXK3OK4LYNtjgaYUyASMpt-KSYO1x-qbgv4", 1).iloc[12:,:].reset_index()

# %%
# df_grade.head()

# %%
df_test = read_spreadsheet('1MHkuutdVoVVeyl_un25nMno2BtCSLCzq8ab6tgwVQKc', 1 )

# %%
df_test.describe()
# Out:
# 0      관리코드  관리계정명   레벨   집계 Source 상세설명   2021/09   2021/10   2021/11  \
# count   171    171  171  171    171  171       171       171       171
# unique  161    168    5    2      3   71        36        44        48
# top          기타수수료    4          GL       0.00E+00  0.00E+00  0.00E+00
# freq     11      2   81  126    129   88       136       127       124
#
# 0        2021/12 2022/1
# count        171    171
# unique        47      2
# top     0.00E+00
# freq         125    170

# %%
df_test.head(-5) 
# filter 관리계정명 == 당기순이익
df_test[df_test['관리계정명'] == '당기순이익']
# Out:
# 0   관리코드  관리계정명 레벨 집계 Source 상세설명     2021/09     2021/10    2021/11  \
# 170       당기순이익  1  Y              -4,460,170  -1,341,766  5,060,890
#
# 0       2021/12 2022/1
# 170  10,114,940

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 1 to 171
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   관리코드     171 non-null    object
#  1   관리계정명    171 non-null    object
#  2   레벨       171 non-null    object
#  3   집계       171 non-null    object
#  4   Source   171 non-null    object
#  5   상세설명     171 non-null    object
#  6   2021/09  171 non-null    object
#  7   2021/10  171 non-null    object
#  8   2021/11  171 non-null    object
#  9   2021/12  171 non-null    object
#  10  2022/1   171 non-null    object
# dtypes: object(11)
# memory usage: 14.8+ KB

# %%
# make wide table to tall 
# Reshaping the data from wide to long format using melt function
long_data = df_test.melt(id_vars=df_test.columns[:6], var_name='Month', value_name='Value')

# Display the first few rows of the reshaped data
long_data.head()
# Out:
#    관리코드                관리계정명 레벨 집계 Source  \
# 0                       영업수익  1  Y
# 1    E1             커머스판매수수료  2  Y     GL
# 2                     쿠팡파트너스  3  Y     GL
# 3  E101         쿠팡파트너스-세금계산서  4        GL
# 4  E102  쿠팡파트너스-Accrual-전월확정  4        GL
#
#                                                 상세설명    Month Value
# 0                                                     2021/09     0
# 1                                                     2021/09     0
# 2                                                     2021/09     0
# 3        익월 25일에 실적 확정. 월별 매출은 세금계산서 발행 기준으로 전월 실적임.  2021/09     0
# 4  당월 실적을 익월 25일에 확정 -> 결산시점에 확인된 당월실적을 기준으로 회계처리...  2021/09     0

# %%
df_test[df_test['관리계정명'] == 'test']
# Out:
# 0   관리코드 관리계정명 레벨 집계 Source 상세설명 2021/09 2021/10 2021/11 2021/12 2022/1
# 171       test                                                        7

# %%
df_test[df_test.columns[6:]].astype(int, errors='ignore')
# Out:
# 0     2021/09   2021/10  2021/11   2021/12 2022/1
# 1           0   4801764   848367  10584911
# 2           0         0        0     99049
# 3           0         0        0     71113
# 4           0         0        0     60999
# 5           0         0        0         0
# ..        ...       ...      ...       ...    ...
# 167         0         0  1554462         0
# 168  -2186188  -8566272  9215054  23441240
# 169         0         0        0     60779
# 170  -4460170  -1341766  5060890  10114940
# 171                                             7
#
# [171 rows x 5 columns]

# %%
df_test
# Out:
# 0    관리코드                관리계정명 레벨 집계 Source  \
# 1                         영업수익  1  Y
# 2      E1             커머스판매수수료  2  Y     GL
# 3                       쿠팡파트너스  3  Y     GL
# 4    E101         쿠팡파트너스-세금계산서  4        GL
# 5    E102  쿠팡파트너스-Accrual-전월확정  4        GL
# ..    ...                  ... .. ..    ...
# 167  D201                  잡손실  3        PL
# 168                       세전이익  1  Y
# 169  D301                  법인세  3        PL
# 170                      당기순이익  1  Y
# 171                       test
#
# 0                                                 상세설명   2021/09   2021/10  \
# 1                                                              0   4801764
# 2                                                              0         0
# 3                                                              0         0
# 4          익월 25일에 실적 확정. 월별 매출은 세금계산서 발행 기준으로 전월 실적임.         0         0
# 5    당월 실적을 익월 25일에 확정 -> 결산시점에 확인된 당월실적을 기준으로 회계처리...         0         0
# ...

# %%
# Out:
# Empty DataFrame
# Columns: [2021/09, 2021/10, 2021/11, 2021/12, 2022/1, Month, Value]
# Index: []

# %%
# # Replace empty strings with NaN in the 'Value' column
# long_data['Value'] = long_data['Value'].replace('', pd.NA)

# # Convert 'Value' column to float
# long_data['Value'] = long_data['Value'].astype(float)

# # Check the data types
# long_data.dtypes

# %%
# agg by month 
# filter level 4
df_long = long_data[long_data['레벨'] == '4'].groupby(['Month']).agg({'Value': 'sum'})

# %%
df_long
# Out:
#                                                      Value
# Month
# 2021/09  0000000000000000000000039248000000000000224343...
# 2021/10  0000000945694001077316000000000003414591559470...
# 2021/11  0000000537113003322580000000000000000000000000...
# 2021/12  6099900000071863700191125400000000000000000000...
# 2022/1

# %%
type (df_long)
# Out:
# pandas.core.frame.DataFrame

# %%
df_long.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 2021/09 to 2022/1
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Value   5 non-null      object
# dtypes: object(1)
# memory usage: 80.0+ bytes

# %%
df_long
# Out:
#                                                      Value
# Month
# 2021/09  0000000000000000000000039248000000000000224343...
# 2021/10  0000000945694001077316000000000003414591559470...
# 2021/11  0000000537113003322580000000000000000000000000...
# 2021/12  6099900000071863700191125400000000000000000000...
# 2022/1

# %%
long_data
# Out:
#      관리코드                관리계정명 레벨 집계 Source  \
# 0                         영업수익  1  Y
# 1      E1             커머스판매수수료  2  Y     GL
# 2                       쿠팡파트너스  3  Y     GL
# 3    E101         쿠팡파트너스-세금계산서  4        GL
# 4    E102  쿠팡파트너스-Accrual-전월확정  4        GL
# ..    ...                  ... .. ..    ...
# 850  D201                  잡손실  3        PL
# 851                       세전이익  1  Y
# 852  D301                  법인세  3        PL
# 853                      당기순이익  1  Y
# 854                       test
#
#                                                   상세설명    Month Value
# 0                                                       2021/09     0
# 1                                                       2021/09     0
# 2                                                       2021/09     0
# 3          익월 25일에 실적 확정. 월별 매출은 세금계산서 발행 기준으로 전월 실적임.  2021/09     0
# 4    당월 실적을 익월 25일에 확정 -> 결산시점에 확인된 당월실적을 기준으로 회계처리...  2021/09     0
# ...

# %%
long_data.astype()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[119], line 1
# ----> 1 long_data.astype()
#
# TypeError: NDFrame.astype() missing 1 required positional argument: 'dtype'

# %%
long_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 855 entries, 0 to 854
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   관리코드    855 non-null    object
#  1   관리계정명   855 non-null    object
#  2   레벨      855 non-null    object
#  3   집계      855 non-null    object
#  4   Source  855 non-null    object
#  5   상세설명    855 non-null    object
#  6   Month   855 non-null    object
#  7   Value   855 non-null    object
# dtypes: object(8)
# memory usage: 53.6+ KB

# %%
long_data['Value'] = pd.to_numeric(long_data['Value'], errors='coerce')

# %%
long_data.groupby(['Month']).agg({'Value': 'sum'})
# Out:
#                Value
# Month
# 2021/09   10566654.0
# 2021/10   20063027.0
# 2021/11   59962829.0
# 2021/12  106298557.0
# 2022/1           7.0

# %% [markdown]
# # 주의 해야하는 부분

# %% [markdown]
# * value type float
# * month type data date ( 2023-01-01)
